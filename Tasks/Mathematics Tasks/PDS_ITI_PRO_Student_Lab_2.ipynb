# %% [markdown]
# # LAB 2: Indepdenece and Random Variables
#
# In this lab you will use python to study the following topics:
#
# - Simulate independent events.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for a dataset.

# %% [markdown]
# # First: you should run this cell

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 1
#
# Use NumPy to create simulations and compute **empirical  probability** for the following outcomes. Compare the results with the **theoretical probability**.
#
# 1. Two fair coin flips produce exactly two heads

# %%
print(f'''Empirical: {((np.random.choice([0, 1], size=10000, p=[0.5, 0.5]) +
                        np.random.choice([0, 1], size=10000, p=[0.5, 0.5]))
                        == 2).mean()}, Theoretical: {0.25}''')
# Out:
# Empirical: 0.2434, Theoretical: 0.25

# %% [markdown]
# 2. Three fair coin flips produce exactly one head

# %%
print(f'''Empirical: {((np.random.choice([0, 1], size=10000, p=[0.5, 0.5]) +
                        np.random.choice([0, 1], size=10000, p=[0.5, 0.5]) +
                        np.random.choice([0, 1], size=10000, p=[0.5, 0.5]))
                        == 1).mean()}, Theoretical: {0.375}''')
# Out:
# Empirical: 0.3777, Theoretical: 0.375

# %% [markdown]
# 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
print(f'''Empirical: {((np.random.choice([0, 1], size=10000, p=[0.4, 0.6]) +
                        np.random.choice([0, 1], size=10000, p=[0.4, 0.6]) +
                        np.random.choice([0, 1], size=10000, p=[0.4, 0.6]))
                        == 1).mean()}, Theoretical: {0.288}''')
# Out:
# Empirical: 0.2927, Theoretical: 0.288

# %% [markdown]
# # Problem 2
#
# The probability of rain in a day is p = 0.5. Give the python code to simulate the probability of rain during weekend (**i.e rain on any one of the 2 weekend days Friday Or Saturday**) (assume independence between raining days). Compare the results with the theoretical probability.

# %% [markdown]
# The probability of rain on a given day (Friday or Saturday) is
# 𝑝
# =
# 0.5
# p=0.5.
# The probability of no rain on a given day is
# 1
# −
# 𝑝
# =
# 0.5
# 1−p=0.5.
# The event "rain on at least one day" can be found by subtracting the probability of "no rain on both days" from 1.
#
# 𝑃
# (
# rain on at least one day
# )
# =
# 1
# −
# 𝑃
# (
# no rain on both days
# )
# P(rain on at least one day)=1−P(no rain on both days)
# 𝑃
# (
# no rain on both days
# )
# =
# 𝑃
# (
# no rain on Friday
# )
# ×
# 𝑃
# (
# no rain on Saturday
# )
# =
# 0.5
# ×
# 0.5
# =
# 0.25
# P(no rain on both days)=P(no rain on Friday)×P(no rain on Saturday)=0.5×0.5=0.25
# 𝑃
# (
# rain on at least one day
# )
# =
# 1
# −
# 0.25
# =
# 0.75
# P(rain on at least one day)=1−0.25=0.75
#
# So, the theoretical probability of rain on either Friday or Saturday is 0.75.

# %%
import numpy as np

num_weekends = 1000

rain_friday = np.random.rand(num_weekends) < 0.5
rain_saturday = np.random.rand(num_weekends) < 0.5

rain_on_weekend = rain_friday | rain_saturday

empirical_probability = np.mean(rain_on_weekend)
print("Empirical Probability of rain on at least one day during the weekend:", empirical_probability)
# Out:
# Empirical Probability of rain on at least one day during the weekend: 0.748

# %% [markdown]
# # Problem 3
# Simulate Rolling a fair die $1000$ times. Then calculate the following:
#
# - Sample mean
# - Sample variance
# - Sample standard deviation
#
# Compare the results with the theoretical probability.

# %%
rolls = np.random.choice([1, 2, 3, 4, 5, 6], size=1000)

sample_mean = np.mean(rolls)
sample_variance = np.var(rolls)
sample_std_dev = np.std(rolls)

print("Sample Mean:", sample_mean)
print("Sample Variance:", sample_variance)
print("Sample Standard Deviation:", sample_std_dev)
# Out:
# Sample Mean: 3.357
# Sample Variance: 2.875551
# Sample Standard Deviation: 1.6957449690327848
